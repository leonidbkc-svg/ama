# %% [markdown]
# <a href="https://colab.research.google.com/github/leonidbkc-svg/ama/blob/main/%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Первые измерения датчиков температуры
print(4, 8, 15, 16, 23, 42)

print ('Hello world')

# Визуализация роста числа пользователей за 7 дней
for i in range(1, 8):
    print('*' * i)

    # Отчёт о доходах по кварталам
print("Отчёт о доходах")
print("1 квартал: 1200000 руб.")
print("2 квартал: 1350000 руб.")
print("3 квартал: 1280000 руб.")
print("4 квартал: 1420000 руб.")

# Приветствие нового аналитика
name = input()  # считываем имя аналитика
print("Добро пожаловать в команду,", name + "!")


# Любимая компания
company = input()  # считываем название компании
print(company, "- лидер рынка!")


# Описание набора данных
dataset_name = input()  # название набора данных
rows = input()          # количество строк
columns = input()       # количество столбцов

print(dataset_name)
print(rows)
print(columns)

# Последние три отчёта
report1 = input()
report2 = input()
report3 = input()

print(report3)
print(report2)
print(report1)

# Рост продаж
base_price = 100
growth_percent = 20

new_price = base_price * (1 + growth_percent / 100)
delta = new_price - base_price

print("new_price =", new_price)
print("delta =", delta)


# Отчёт по регионам
print("Северный***Центральный***Южный")

# Приветствие при подключении к базе данных
name = input()
print("Подключение установлено.", end=" ")
print("Добро пожаловать,", name + "!")

# Отчёт о продажах
separator = input()   # считываем разделитель
product1 = input()    # первый товар
product2 = input()    # второй товар
product3 = input()    # третий товар

print(product1, product2, product3, sep=f" {separator} ")

# Целая часть числа
value_str = "42.7"

integer_part = int(float(value_str))

print(integer_part)



# Абсолютное отклонение от плана
orders_yesterday = 10
plan = 20

abs_diff = abs(plan - orders_yesterday)

print("Абсолютное отклонение от плана равняется", abs_diff)


# Наибольшее и наименьшее
num1 = int(input())
num2 = int(input())
num3 = int(input())
num4 = int(input())
num5 = int(input())

print("Наименьшее число =", min(num1, num2, num3, num4, num5))
print("Наибольшее число =", max(num1, num2, num3, num4, num5))



# Приветствие нового пользователя
first_name = input()
last_name = input()

print("Привет, " + first_name + " " + last_name + "! Вы только что начали изучать Python")




# Цитата Стива Джобса
part1 = input()
part2 = input()

print('"' + part1 + " " + part2 + '"')


# Проверка скидки
amount = float(input())
print(amount > 1000)



# Проверка возраста пользователя
age = int(input())
print(age >= 18)



# Встреча потоков данных
S = float(input())   # расстояние между потоками (МБ)
V1 = float(input())  # скорость первого потока (МБ/ч)
V2 = float(input())  # скорость второго потока (МБ/ч)

t = S / (V1 + V2)
print(t)



# Площадь прямоугольного треугольника
a = float(input())  # длина первого катета
b = float(input())  # длина второго катета

S = a * b / 2
print(S)


# 451 градус по Фаренгейту — перевод в Цельсий
tF = float(input())  # температура по Фаренгейту
tC = (5 / 9) * (tF - 32)
print(tC)

# Расчёт бонуса для курьера
revenue_str = input()      # строка с выручкой, например 438746.78
courier_name = input()     # имя курьера, например Влад

revenue = float(revenue_str)       # преобразуем строку в число
bonus = int(revenue * 0.01)        # вычисляем 1% и округляем вниз
report = "Курьер " + courier_name + " получит бонус " + str(bonus) + " р."

print(report)
7
# Out:
# 4 8 15 16 23 42
# Hello world
# *
# **
# ***
# ****
# *****
# ******
# *******
# Отчёт о доходах
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.
# йцу
# Добро пожаловать в команду, йцу!
# йуй
# йуй - лидер рынка!
# уйуйув
# 1
# 3
# уйуйув
# 1
# 3
# 4
# 56
#
#
# 56
# 4
# new_price = 120.0
# delta = 20.0
# Северный***Центральный***Южный
#
# Подключение установлено. Добро пожаловать, !
#
# 7
# 1
# 3
# 7  1  3
# 42
# Абсолютное отклонение от плана равняется 10
# 1
# 3
# 3
# 5
# 7
# Наименьшее число = 1
# Наибольшее число = 7
#
# 7
# Привет,  7! Вы только что начали изучать Python
# 1
# 55
# "1 55"
# 656
# False
# 13
# False
# 31
# 31
# 54
# 0.36470588235294116
# 13
# 31
# 201.5
# 45
# 7.222222222222222
# 44
# 1
# Курьер 1 получит бонус 0 р.
