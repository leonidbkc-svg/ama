# %% [markdown]
# <a href="https://colab.research.google.com/github/leonidbkc-svg/ama/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ввод данных
password = input()
confirm = input()

# Проверка совпадения
if password == confirm:
    print("Пароль принят")
else:
    print("Пароль не принят")

   # Ввод возраста
age = int(input())

# Проверка возраста
if age >= 18:
    print("Доступ разрешен")
else:
    print("Доступ запрещен")

# Ввод данных
a = int(input())
b = int(input())

# Вывод меньшего числа
if a < b:
    print(a)
else:
    print(b)
# Ввод данных
a = int(input())
b = int(input())
c = int(input())


# Ввод данных
a = int(input())
b = int(input())
c = int(input())

# Проверка условия арифметической прогрессии
if b - a == c - b:
    print("Да")
else:
    print("Нет")


# Задание №5
a = int(input())
b = int(input())
c = int(input())
total = 0
if a > 0:
    total += a
if b > 0:
    total += b
if c > 0:
    total += c
print(total)

# Задание №6
a = int(input())
b = int(input())
c = int(input())
d = int(input())
min_num = a
if b < min_num:
    min_num = b
if c < min_num:
    min_num = c
if d < min_num:
    min_num = d
print(min_num)

# Задание №7
year = int(input())
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Да")
else:
    print("Нет")

# Задание №8
a = int(input())
b = int(input())
c = int(input())
if (a <= b <= c) or (c <= b <= a):
    print(b)
elif (b <= a <= c) or (c <= a <= b):
    print(a)
else:
    print(c)

# Задание №9
for i in range(10):
    print("Войти в IT с Python")

# Задание №10
n = int(input())
for _ in range(n):
    print("*" * 19)

# Задание №11
text = input()
for i in range(10):
    print(i, text)

# Задание №12
n = int(input())
a, b = 1, 1
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b

# Задание №13
n = int(input())
factorial = 1
for i in range(1, n + 1):
    factorial *= i
print(factorial)

# Задание №14
while True:
    word = input()
    if word == "стоп":
        break
    print(word)

# Задание №15
total = 0
while True:
    num = int(input())
    if num < 0:
        break
    total += num
print(total)

# Задание №16
def draw_triangle():+
    for i in range(1, 8):
        print("*" * i)
draw_triangle()

# Задание №17
def print_fio(name, surname, patronymic):
    print(surname[0].upper() + name[0].upper() + patronymic[0].upper())
name = input()
surname = input()
patronymic = input()
print_fio(name, surname, patronymic)

# Задание №18
def sum_of_squares():
    total = 0
    squares = 0
    while True:
        num = int(input())
        total += num
        squares += num ** 2
        if total == 0:
            break
    print(squares)
sum_of_squares()

# Задание №19
def convert_to_miles(km):
    return km * 0.6214
km = float(input())
print(convert_to_miles(km))
# Out:
# 45
# 4545
# Пароль не принят
# 4551
# Доступ разрешен
# 15564
# 12564
# 12564
# 2012103
# 12
# 12
# 12
# 023
# 12
# Нет
# 12
# 425
# 4554
# 4991
# 4512
# 1
# 11
# 1
# 1
# 1
# Нет
# 4
# 4
# 1
# 4
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# 4
# *******************
# *******************
# *******************
# *******************
# 4
# 0 4
# 1 4
# 2 4
# 3 4
# 4 4
# 5 4
# 6 4
# 7 4
# 8 4
# 9 4
# 4
# 1 1 2 3 4
# 24
# 7
# 7
# 7
# 7
# 53274
# 53274
# 524
# 524
# 44
# 44
# 44
# 44
# 44
# 44
# 7
# 7
# 7
# 7
# 5
# 5
# 41
# 41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3346019483.py in <cell line: 0>()
#     120 # Задание №14
#     121 while True:
# --> 122     word = input()
# ...
